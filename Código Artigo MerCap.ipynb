# %%
import pandas as pd
import numpy as np
import statsmodels.regression.linear_model as lm
import statsmodels.tools.tools as tool
#import pandas_datareader as reader

# %%
#!pip install pandas_datareader
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
'Tabelas retiradas do Nefin, fatores do FF5'

rf = pd.read_excel(r'C:\Users\lucas\Risk_Free.xls')
mr = pd.read_excel(r'C:\Users\lucas\Market_Factor.xls')
iml = pd.read_excel(r'C:\Users\lucas\IML_Factor.xls')
wml = pd.read_excel(r'C:\Users\lucas\WML_Factor.xls')
hml = pd.read_excel(r'C:\Users\lucas\HML_Factor.xls')
smb = pd.read_excel(r'C:\Users\lucas\SMB_Factor.xls')

# %%
'Market Risk Factor'
mr
factors = ['rf','mr','iml','wml','hml','smb']

# %%
factors
s_m_b = smb['SMB']
r_free = rf['Risk_free']
m_risk = mr['Rm_minus_Rf']
i_m_l = iml['IML']
w_m_l = wml['WML']
h_m_l = hml['HML']

# %%
table = pd.concat([rf,m_risk,s_m_b,i_m_l,w_m_l,h_m_l],axis = 1)
table
# Out:
#       year  month  day  Risk_free  Rm_minus_Rf       SMB       IML       WML  \
# 0     2001      1    2   0.000579     0.006601  0.000524  0.014109 -0.006308
# 1     2001      1    3   0.000577     0.062427  0.005390  0.004510 -0.028644
# 2     2001      1    4   0.000574    -0.000310  0.006690 -0.009227 -0.000946
# 3     2001      1    5   0.000573    -0.012839  0.003523  0.025124  0.005985
# 4     2001      1    8   0.000573     0.003982  0.007883 -0.001175 -0.004099
# ...    ...    ...  ...        ...          ...       ...       ...       ...
# 5337  2022      7   25   0.000502     0.011627 -0.015462 -0.014896  0.025842
# 5338  2022      7   26   0.000502    -0.006211 -0.004139  0.003451  0.017244
# 5339  2022      7   27   0.000503     0.018606  0.003668  0.000251 -0.013883
# 5340  2022      7   28   0.000504     0.012144  0.015803  0.013891 -0.018464
# 5341  2022      7   29   0.000504     0.003880 -0.000330  0.002994  0.015212
#
#            HML
# 0     0.065490
# ...

# %%
table.to_csv('tabelaff5.csv')
table.to_excel('tabelaff5.xlsx')

# %%
pd.read_excel(r'C:\Users\lucas\tabelaff5.xlsx', engine = 'openpyxl')
# Out:
#       Unnamed: 0  year  month  day  Risk_free  Rm_minus_Rf       SMB  \
# 0              0  2001      1    2   0.000579     0.006601  0.000524
# 1              1  2001      1    3   0.000577     0.062427  0.005390
# 2              2  2001      1    4   0.000574    -0.000310  0.006690
# 3              3  2001      1    5   0.000573    -0.012839  0.003523
# 4              4  2001      1    8   0.000573     0.003982  0.007883
# ...          ...   ...    ...  ...        ...          ...       ...
# 5337        5337  2022      7   25   0.000502     0.011627 -0.015462
# 5338        5338  2022      7   26   0.000502    -0.006211 -0.004139
# 5339        5339  2022      7   27   0.000503     0.018606  0.003668
# 5340        5340  2022      7   28   0.000504     0.012144  0.015803
# 5341        5341  2022      7   29   0.000504     0.003880 -0.000330
#
#            IML       WML       HML
# 0     0.014109 -0.006308  0.065490
# 1     0.004510 -0.028644  0.009390
# ...

# %%
portfo = [
'3_portfolios_sorted_by_book-to-market.xls',
'3_portfolios_sorted_by_illiquidity.xls',
'3_portfolios_sorted_by_momentum.xls',
'3_portfolios_sorted_by_size.xls',
'4_portfolios_sorted_by_book-to-market.xls',
'4_portfolios_sorted_by_momentum.xls',
'4_portfolios_sorted_by_size_and_illiquidity_2x2.xls',
'7_portfolios_sorted_by_industry.xls'
]

# %%
pd.read_excel(portfo[1],index_col = [3,4,5])
# Out:
#                                year  month  day
# ILLIQ1    ILLIQ2    ILLIQ3
# -0.004060  0.056667  0.010050  2001      1    2
#  0.083359  0.066460  0.087870  2001      1    3
#  0.004371 -0.007698 -0.004856  2001      1    4
# -0.018392 -0.012300  0.006732  2001      1    5
#  0.007301  0.002004  0.006126  2001      1    8
# ...                             ...    ...  ...
#  0.006357 -0.003718 -0.008539  2022      7   25
# -0.011952 -0.015663 -0.008501  2022      7   26
#  0.027146  0.030376  0.027397  2022      7   27
#  0.010043  0.014912  0.023934  2022      7   28
# -0.002981 -0.004849  0.000013  2022      7   29
#
# [5342 rows x 3 columns]

# %%
btm = pd.read_excel(portfo[0])
ill = pd.read_excel(portfo[1])
# Out:
#       year  month  day       BM1       BM2       BM3
# 0     2001      1    2 -0.008021 -0.009106  0.057469
# 1     2001      1    3  0.071020  0.062202  0.080410
# 2     2001      1    4  0.000997  0.007383 -0.001331
# 3     2001      1    5 -0.008905 -0.006156 -0.011302
# 4     2001      1    8  0.006843  0.009757  0.008791
# ...    ...    ...  ...       ...       ...       ...
# 5337  2022      7   25 -0.006279  0.002183 -0.005407
# 5338  2022      7   26 -0.020302 -0.013799 -0.009462
# 5339  2022      7   27  0.036816  0.027114  0.026482
# 5340  2022      7   28  0.025572  0.014758  0.013086
# 5341  2022      7   29 -0.000984 -0.000049 -0.003263
#
# [5342 rows x 6 columns]

# %%
names=['3_btm.xls',
'3_ill.xls',
'3_mom.xls',
'3_siz.xls',
'4_btm.xls',
'4_mom.xls',
'4_SaL.xls',
'7_ind.xls']

for i in range(8):
    print(names[i] + '= pd.read_excel(portfo[' + str(i) + '])')
# Out:
# 3_btm.xls= pd.read_excel(portfo[0])
# 3_ill.xls= pd.read_excel(portfo[1])
# 3_mom.xls= pd.read_excel(portfo[2])
# 3_siz.xls= pd.read_excel(portfo[3])
# 4_btm.xls= pd.read_excel(portfo[4])
# 4_mom.xls= pd.read_excel(portfo[5])
# 4_SaL.xls= pd.read_excel(portfo[6])
# 7_ind.xls= pd.read_excel(portfo[7])

# %%
btm_3 = pd.read_excel(portfo[0])
ill_3 = pd.read_excel(portfo[1])
mom_3 = pd.read_excel(portfo[2])
siz_3 = pd.read_excel(portfo[3])
btm_4 = pd.read_excel(portfo[4])
mom_4 = pd.read_excel(portfo[5])
SaL_4 = pd.read_excel(portfo[6])
ind_7 = pd.read_excel(portfo[7])

# %%
ind_7
# Out:
#       year  month  day  Industry_1  Industry_2  Industry_3  Industry_4  \
# 0     2001      1    2   -0.008949         NaN   -0.001977   -0.002255
# 1     2001      1    3    0.049927         NaN    0.061688    0.092555
# 2     2001      1    4    0.031552         NaN    0.004532   -0.017185
# 3     2001      1    5   -0.013545         NaN   -0.012516    0.001496
# 4     2001      1    8    0.013573         NaN    0.005060    0.011969
# ...    ...    ...  ...         ...         ...         ...         ...
# 5316  2022      6   24    0.007355   -0.008803   -0.004209    0.004586
# 5317  2022      6   27    0.012354    0.005741   -0.000056    0.020349
# 5318  2022      6   28   -0.009266   -0.021906   -0.016104    0.006041
# 5319  2022      6   29   -0.012676   -0.014601   -0.015574   -0.008495
# 5320  2022      6   30   -0.013238   -0.004738   -0.014590   -0.015126
#
#       Industry_5  Industry_6  Industry_7
# 0       0.137751    0.018988   -0.013664
# ...

# %%
portfolio = pd.concat([btm_3, ill_3, mom_3, siz_3, btm_4, mom_4, SaL_4, ind_7],axis = 1)

# %%
#Dates: 01.02.2009 to 06.30.2022
start = 1983
end = 5321

# %%
portfolio[start:end]
# Out:
#       year  month  day       BM1       BM2       BM3  year  month  day  \
# 1983  2009      1    2  0.039834  0.050822  0.035725  2009      1    2
# 1984  2009      1    5  0.017381  0.018866  0.009044  2009      1    5
# 1985  2009      1    6  0.015873  0.017221  0.015948  2009      1    6
# 1986  2009      1    7 -0.022053 -0.001265 -0.011567  2009      1    7
# 1987  2009      1    8  0.029023  0.011318  0.018518  2009      1    8
# ...    ...    ...  ...       ...       ...       ...   ...    ...  ...
# 5316  2022      6   24 -0.005671  0.001818  0.000579  2022      6   24
# 5317  2022      6   27 -0.001258  0.012248  0.005086  2022      6   27
# 5318  2022      6   28 -0.019315 -0.007437 -0.012411  2022      6   28
# 5319  2022      6   29 -0.014158 -0.013160 -0.012411  2022      6   29
# 5320  2022      6   30 -0.006079 -0.012501 -0.011447  2022      6   30
#
#         ILLIQ1  ...    year  month   day  Industry_1  Industry_2  Industry_3  \
# ...

# %%
portfolio[start:end] == portfolio[1983:5321]
# Out:
#       year  month   day   BM1   BM2   BM3  year  month   day  ILLIQ1  ...  \
# 1983  True   True  True  True  True  True  True   True  True    True  ...
# 1984  True   True  True  True  True  True  True   True  True    True  ...
# 1985  True   True  True  True  True  True  True   True  True    True  ...
# 1986  True   True  True  True  True  True  True   True  True    True  ...
# 1987  True   True  True  True  True  True  True   True  True    True  ...
# ...    ...    ...   ...   ...   ...   ...   ...    ...   ...     ...  ...
# 5316  True   True  True  True  True  True  True   True  True    True  ...
# 5317  True   True  True  True  True  True  True   True  True    True  ...
# 5318  True   True  True  True  True  True  True   True  True    True  ...
# 5319  True   True  True  True  True  True  True   True  True    True  ...
# 5320  True   True  True  True  True  True  True   True  True    True  ...
#
#       year  month   day  Industry_1  Industry_2  Industry_3  Industry_4  \
# ...

# %%
portfolio = portfolio[start:end]
portfolio.to_csv('carteirasnefin.csv')
portfolio.to_excel('carteirasnefin.xlsx')

# %%
'Importando as tabelas'

factor = pd.read_excel('tabelaff5.xlsx')
portfolio = pd.read_excel('carteirasnefin.xlsx')

# %%
factors=factor[start:end]
factors
# Out:
#       Unnamed: 0  year  month  day  Risk_free  Rm_minus_Rf       SMB  \
# 1983        1983  2009      1    2   0.000497     0.066011 -0.021431
# 1984        1984  2009      1    5   0.000498     0.017156  0.007281
# 1985        1985  2009      1    6   0.000497     0.013712  0.033590
# 1986        1986  2009      1    7   0.000497    -0.033140  0.034295
# 1987        1987  2009      1    8   0.000495     0.021585 -0.002022
# ...          ...   ...    ...  ...        ...          ...       ...
# 5316        5316  2022      6   24   0.000490     0.004059 -0.003098
# 5317        5317  2022      6   27   0.000490     0.016713 -0.005018
# 5318        5318  2022      6   28   0.000490    -0.002726 -0.016777
# 5319        5319  2022      6   29   0.000490    -0.009463 -0.009097
# 5320        5320  2022      6   30   0.000490    -0.010756 -0.000273
#
#            IML       WML       HML
# 1983 -0.027757  0.000562 -0.004108
# 1984 -0.005035 -0.023794 -0.008337
# ...

# %%
unido = pd.concat([factors,portfolio],axis = 1)

# %%
unido[0:3338]
# Out:
#       Unnamed: 0    year  month   day  Risk_free  Rm_minus_Rf       SMB  \
# 1983      1983.0  2009.0    1.0   2.0   0.000497     0.066011 -0.021431
# 1984      1984.0  2009.0    1.0   5.0   0.000498     0.017156  0.007281
# 1985      1985.0  2009.0    1.0   6.0   0.000497     0.013712  0.033590
# 1986      1986.0  2009.0    1.0   7.0   0.000497    -0.033140  0.034295
# 1987      1987.0  2009.0    1.0   8.0   0.000495     0.021585 -0.002022
# ...          ...     ...    ...   ...        ...          ...       ...
# 5316      5316.0  2022.0    6.0  24.0   0.000490     0.004059 -0.003098
# 5317      5317.0  2022.0    6.0  27.0   0.000490     0.016713 -0.005018
# 5318      5318.0  2022.0    6.0  28.0   0.000490    -0.002726 -0.016777
# 5319      5319.0  2022.0    6.0  29.0   0.000490    -0.009463 -0.009097
# 5320      5320.0  2022.0    6.0  30.0   0.000490    -0.010756 -0.000273
#
#            IML       WML       HML  ...  year.7  month.7  day.7  Industry_1  \
# ...

# %%
unido.to_csv('tabelaunida.csv')
unido.to_excel('tabelaunida.xlsx')

# %%
tabela = pd.read_excel('artigomacrocorrigido.xlsx')

# %%
tabela
# Out:
#       Unnamed: 0.1  Unnamed: 0    year  month   day  Risk_free  Rm_minus_Rf  \
# 0           1983.0      1983.0  2009.0    1.0   2.0   0.000497     0.066011
# 1           1984.0      1984.0  2009.0    1.0   5.0   0.000498     0.017156
# 2           1985.0      1985.0  2009.0    1.0   6.0   0.000497     0.013712
# 3           1986.0      1986.0  2009.0    1.0   7.0   0.000497    -0.033140
# 4           1987.0      1987.0  2009.0    1.0   8.0   0.000495     0.021585
# ...            ...         ...     ...    ...   ...        ...          ...
# 3333        5316.0      5316.0  2022.0    6.0  24.0   0.000490     0.004059
# 3334        5317.0      5317.0  2022.0    6.0  27.0   0.000490     0.016713
# 3335        5318.0      5318.0  2022.0    6.0  28.0   0.000490    -0.002726
# 3336        5319.0      5319.0  2022.0    6.0  29.0   0.000490    -0.009463
# 3337        5320.0      5320.0  2022.0    6.0  30.0   0.000490    -0.010756
#
# ...

# %% [markdown]
# # CAPM
#
# $r_i-r_f = \beta_1\cdot(r_m-r_f) + \epsilon$
#
# # Modelo de 3 fatores:
#
# $r_i-r_f = \beta_1\cdot(r_m-r_f) +\beta_2\cdot (SMB) + \beta_3\cdot (HML) + \epsilon$
#
# # Modelo de 5 fatores:
#
# $r_i-r_f = \beta_1\cdot(r_m-r_f) +\beta_2\cdot (SMB) + \beta_3\cdot (HML) + \beta_4\cdot (IML) +\beta_5\cdot (WML) + \epsilon$

# %%
import statsmodels.regression.linear_model as lm
import statsmodels.tools.tools as tool
import numpy as np
import pandas as pd

# %%
'Dados:'
tabela = pd.read_csv('tabela2009ing.csv', index_col = 'year-month-day', parse_dates = True)

# %%
tabela.columns
# Out:
# Index(['Risk_free', 'Rm_minus_Rf', 'SMB', 'IML', 'WML', 'HML', 'BM1', 'BM2',
#        'BM3', 'ILLIQ1', 'ILLIQ2', 'ILLIQ3', 'Mom1', 'Mom2', 'Mom3', 'Size1',
#        'Size2', 'Size3', 'BM1.1', 'BM2.1', 'BM3.1', 'BM4', 'Mom1.1', 'Mom2.1',
#        'Mom3.1', 'Mom4', 'Size1_ILLIQ1', 'Size1_ILLIQ2', 'Size2_ILLIQ1',
#        'Size2_ILLIQ2', 'Industry_1', 'Industry_2', 'Industry_3', 'Industry_4',
#        'Industry_5', 'Industry_6', 'Industry_7'],
#       dtype='object')

# %%
bm = tabela.columns[11:14]

# %%
tabela[['Risk_free','SMB']]
# Out:
#                 Risk_free       SMB
# year-month-day
# 2009-01-02       0.000497 -0.021431
# 2009-01-05       0.000498  0.007281
# 2009-01-06       0.000497  0.033590
# 2009-01-07       0.000497  0.034295
# 2009-01-08       0.000495 -0.002022
# ...                   ...       ...
# 2022-06-24       0.000490 -0.003098
# 2022-06-27       0.000490 -0.005018
# 2022-06-28       0.000490 -0.016777
# 2022-06-29       0.000490 -0.009097
# 2022-06-30       0.000490 -0.000273
#
# [3338 rows x 2 columns]

# %%
#tabela.loc[:,'CT'] = tool.add_constant(tabela)
capm = lm.OLS(tabela['BM1'],tabela[['Rm_minus_Rf']], hasconst = bool).fit()
print(capm.summary())
capm.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    BM1   R-squared:                       0.794
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 31 Aug 2022   Prob (F-statistic):                nan
# Time:                        17:37:32   Log-Likelihood:                 12142.
# No. Observations:                3338   AIC:                        -2.428e+04
# Df Residuals:                    3337   BIC:                        -2.428e+04
# Df Model:                           0
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Rm_minus_Rf     0.8773      0.008    113.449      0.000       0.862       0.892
# ...

# %%
ff3fm = lm.OLS(tabela['BM1'],tabela[['Rm_minus_Rf','SMB','HML']], hasconst = bool).fit()
print(ff3fm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    BM1   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                 1.873e+04
# Date:                Wed, 31 Aug 2022   Prob (F-statistic):               0.00
# Time:                        17:36:57   Log-Likelihood:                 13686.
# No. Observations:                3338   AIC:                        -2.737e+04
# Df Residuals:                    3335   BIC:                        -2.735e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Rm_minus_Rf     0.9465      0.005    190.035      0.000       0.937       0.956
# ...

# %%
ff5fm = lm.OLS(tabela['BM1'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']], hasconst = bool).fit()
print(ff5fm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    BM1   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     9379.
# Date:                Wed, 31 Aug 2022   Prob (F-statistic):               0.00
# Time:                        17:37:00   Log-Likelihood:                 13689.
# No. Observations:                3338   AIC:                        -2.737e+04
# Df Residuals:                    3333   BIC:                        -2.734e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Rm_minus_Rf     0.9522      0.006    171.061      0.000       0.941       0.963
# ...

# %%
'-------------------------Carteira BM1 -------------------------' 
capm=lm.OLS(tabela['BM1'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['BM1'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['BM1'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira BM2 -------------------------' 
capm=lm.OLS(tabela['BM2'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['BM2'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['BM2'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira BM3 -------------------------' 
capm=lm.OLS(tabela['BM3'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['BM3'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['BM3'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira ILLIQ1 -------------------------' 
capm=lm.OLS(tabela['ILLIQ1'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['ILLIQ1'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['ILLIQ1'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira ILLIQ2 -------------------------' 
capm=lm.OLS(tabela['ILLIQ2'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['ILLIQ2'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['ILLIQ2'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira ILLIQ3 -------------------------' 
capm=lm.OLS(tabela['ILLIQ3'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['ILLIQ3'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['ILLIQ3'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Mom1 -------------------------' 
capm=lm.OLS(tabela['Mom1'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Mom1'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Mom1'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Mom2 -------------------------' 
capm=lm.OLS(tabela['Mom2'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Mom2'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Mom2'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Mom3 -------------------------' 
capm=lm.OLS(tabela['Mom3'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Mom3'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Mom3'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Size1 -------------------------' 
capm=lm.OLS(tabela['Size1'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Size1'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Size1'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Size2 -------------------------' 
capm=lm.OLS(tabela['Size2'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Size2'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Size2'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Size3 -------------------------' 
capm=lm.OLS(tabela['Size3'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Size3'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Size3'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira BM1.1 -------------------------' 
capm=lm.OLS(tabela['BM1.1'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['BM1.1'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['BM1.1'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira BM2.1 -------------------------' 
capm=lm.OLS(tabela['BM2.1'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['BM2.1'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['BM2.1'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira BM3.1 -------------------------' 
capm=lm.OLS(tabela['BM3.1'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['BM3.1'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['BM3.1'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira BM4 -------------------------' 
capm=lm.OLS(tabela['BM4'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['BM4'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['BM4'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Mom1.1 -------------------------' 
capm=lm.OLS(tabela['Mom1.1'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Mom1.1'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Mom1.1'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Mom2.1 -------------------------' 
capm=lm.OLS(tabela['Mom2.1'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Mom2.1'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Mom2.1'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Mom3.1 -------------------------' 
capm=lm.OLS(tabela['Mom3.1'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Mom3.1'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Mom3.1'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Mom4 -------------------------' 
capm=lm.OLS(tabela['Mom4'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Mom4'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Mom4'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Size1_ILLIQ1 -------------------------' 
capm=lm.OLS(tabela['Size1_ILLIQ1'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Size1_ILLIQ1'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Size1_ILLIQ1'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Size1_ILLIQ2 -------------------------' 
capm=lm.OLS(tabela['Size1_ILLIQ2'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Size1_ILLIQ2'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Size1_ILLIQ2'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Size2_ILLIQ1 -------------------------' 
capm=lm.OLS(tabela['Size2_ILLIQ1'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Size2_ILLIQ1'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Size2_ILLIQ1'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Size2_ILLIQ2 -------------------------' 
capm=lm.OLS(tabela['Size2_ILLIQ2'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Size2_ILLIQ2'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Size2_ILLIQ2'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Industry_1 -------------------------' 
capm=lm.OLS(tabela['Industry_1'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Industry_1'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Industry_1'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Industry_2 -------------------------' 
capm=lm.OLS(tabela['Industry_2'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Industry_2'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Industry_2'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Industry_3 -------------------------' 
capm=lm.OLS(tabela['Industry_3'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Industry_3'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Industry_3'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Industry_4 -------------------------' 
capm=lm.OLS(tabela['Industry_4'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Industry_4'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Industry_4'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Industry_5 -------------------------' 
capm=lm.OLS(tabela['Industry_5'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Industry_5'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Industry_5'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Industry_6 -------------------------' 
capm=lm.OLS(tabela['Industry_6'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Industry_6'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Industry_6'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Industry_7 -------------------------' 
capm=lm.OLS(tabela['Industry_7'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Industry_7'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Industry_7'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    BM1   R-squared:                       0.794
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 31 Aug 2022   Prob (F-statistic):                nan
# Time:                        17:58:08   Log-Likelihood:                 12142.
# No. Observations:                3338   AIC:                        -2.428e+04
# Df Residuals:                    3337   BIC:                        -2.428e+04
# Df Model:                           0
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Rm_minus_Rf     0.8773      0.008    113.449      0.000       0.862       0.892
# ...

# %%
'-------------------------Carteira BM1 -------------------------' 
capm=lm.OLS(tabela['BM1']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['BM1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['BM1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira BM2 -------------------------' 
capm=lm.OLS(tabela['BM2']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['BM2']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['BM2']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira BM3 -------------------------' 
capm=lm.OLS(tabela['BM3']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['BM3']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['BM3']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira ILLIQ1 -------------------------' 
capm=lm.OLS(tabela['ILLIQ1']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['ILLIQ1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['ILLIQ1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira ILLIQ2 -------------------------' 
capm=lm.OLS(tabela['ILLIQ2']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['ILLIQ2']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['ILLIQ2']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira ILLIQ3 -------------------------' 
capm=lm.OLS(tabela['ILLIQ3']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['ILLIQ3']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['ILLIQ3']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Mom1 -------------------------' 
capm=lm.OLS(tabela['Mom1']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Mom1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Mom1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Mom2 -------------------------' 
capm=lm.OLS(tabela['Mom2']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Mom2']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Mom2']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Mom3 -------------------------' 
capm=lm.OLS(tabela['Mom3']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Mom3']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Mom3']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Size1 -------------------------' 
capm=lm.OLS(tabela['Size1']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Size1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Size1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Size2 -------------------------' 
capm=lm.OLS(tabela['Size2']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Size2']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Size2']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Size3 -------------------------' 
capm=lm.OLS(tabela['Size3']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Size3']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Size3']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira BM1.1 -------------------------' 
capm=lm.OLS(tabela['BM1.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['BM1.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['BM1.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira BM2.1 -------------------------' 
capm=lm.OLS(tabela['BM2.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['BM2.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['BM2.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira BM3.1 -------------------------' 
capm=lm.OLS(tabela['BM3.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['BM3.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['BM3.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira BM4 -------------------------' 
capm=lm.OLS(tabela['BM4']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['BM4']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['BM4']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Mom1.1 -------------------------' 
capm=lm.OLS(tabela['Mom1.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Mom1.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Mom1.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Mom2.1 -------------------------' 
capm=lm.OLS(tabela['Mom2.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Mom2.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Mom2.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Mom3.1 -------------------------' 
capm=lm.OLS(tabela['Mom3.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Mom3.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Mom3.1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Mom4 -------------------------' 
capm=lm.OLS(tabela['Mom4']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Mom4']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Mom4']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Size1_ILLIQ1 -------------------------' 
capm=lm.OLS(tabela['Size1_ILLIQ1']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Size1_ILLIQ1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Size1_ILLIQ1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Size1_ILLIQ2 -------------------------' 
capm=lm.OLS(tabela['Size1_ILLIQ2']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Size1_ILLIQ2']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Size1_ILLIQ2']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Size2_ILLIQ1 -------------------------' 
capm=lm.OLS(tabela['Size2_ILLIQ1']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Size2_ILLIQ1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Size2_ILLIQ1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Size2_ILLIQ2 -------------------------' 
capm=lm.OLS(tabela['Size2_ILLIQ2']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Size2_ILLIQ2']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Size2_ILLIQ2']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Industry_1 -------------------------' 
capm=lm.OLS(tabela['Industry_1']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Industry_1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Industry_1']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Industry_2 -------------------------' 
capm=lm.OLS(tabela['Industry_2']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Industry_2']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Industry_2']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Industry_3 -------------------------' 
capm=lm.OLS(tabela['Industry_3']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Industry_3']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Industry_3']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Industry_4 -------------------------' 
capm=lm.OLS(tabela['Industry_4']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Industry_4']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Industry_4']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Industry_5 -------------------------' 
capm=lm.OLS(tabela['Industry_5']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Industry_5']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Industry_5']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Industry_6 -------------------------' 
capm=lm.OLS(tabela['Industry_6']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Industry_6']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Industry_6']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
'-------------------------Carteira Industry_7 -------------------------' 
capm=lm.OLS(tabela['Industry_7']-tabela['Risk_free'],tabela[['Rm_minus_Rf']],hasconst=bool).fit() 
print(capm.summary()) 
ff3fm=lm.OLS(tabela['Industry_7']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','HML']],hasconst=bool).fit() 
print(ff3fm.summary()) 
ff5fm=lm.OLS(tabela['Industry_7']-tabela['Risk_free'],tabela[['Rm_minus_Rf','SMB','IML','WML','HML']],hasconst=bool).fit() 
print(ff5fm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.794
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 31 Aug 2022   Prob (F-statistic):                nan
# Time:                        18:22:46   Log-Likelihood:                 12146.
# No. Observations:                3338   AIC:                        -2.429e+04
# Df Residuals:                    3337   BIC:                        -2.428e+04
# Df Model:                           0
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Rm_minus_Rf     0.8772      0.008    113.590      0.000       0.862       0.892
# ...
